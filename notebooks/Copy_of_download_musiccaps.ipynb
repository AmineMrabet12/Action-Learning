# %% [markdown]
# # Downloading Clips from the MusicCaps Dataset
#
# In this notebook, we see how you can use `yt-dlp` to download clips from the [MusicCaps](https://huggingface.co/datasets/google/MusicCaps) dataset from Google. The MusicCaps dataset contains music and their associated text captions. You could use a dataset like this to train a text-to-audio generation model 😉.
#
# Once we've downloaded the clips, we'll explore them using a [Gradio](https://gradio.app/) interface.
#
# If you like this notebook:
#
#   - consider giving the [repo](https://github.com/nateraw/download-musiccaps-dataset) a star ⭐️
#   - consider following me on Github [@nateraw](https://github.com/nateraw)

# %%
# %%capture
! pip install datasets[audio] yt-dlp

# For the interactive interface we'll need gradio
! pip install gradio

# %%
import subprocess
import os
from pathlib import Path

from datasets import load_dataset, Audio


def download_clip(
    video_identifier,
    output_filename,
    start_time,
    end_time,
    tmp_dir='/data/MusicCaps',
    num_attempts=5,
    url_base='https://www.youtube.com/watch?v='
):
    status = False

    command = f"""
        yt-dlp --quiet --force-keyframes-at-cuts --no-warnings -x --audio-format wav -f bestaudio -o "{output_filename}" --download-sections "*{start_time}-{end_time}" {url_base}{video_identifier}
    """.strip()

    attempts = 0
    while True:
        try:
            output = subprocess.check_output(command, shell=True,
                                                stderr=subprocess.STDOUT)
        except subprocess.CalledProcessError as err:
            attempts += 1
            if attempts == num_attempts:
                return status, err.output
        else:
            break

    # Check if the video was successfully saved.
    status = os.path.exists(output_filename)
    return status, 'Downloaded'


def main(
    data_dir: str,
    sampling_rate: int = 44100,
    limit: int = None,
    num_proc: int = 1,
    writer_batch_size: int = 1000,
):
    """
    Download the clips within the MusicCaps dataset from YouTube.
    Args:
        data_dir: Directory to save the clips to.
        sampling_rate: Sampling rate of the audio clips.
        limit: Limit the number of examples to download.
        num_proc: Number of processes to use for downloading.
        writer_batch_size: Batch size for writing the dataset. This is per process.
    """

    ds = load_dataset('google/MusicCaps', split='train')
    if limit is not None:
        print(f"Limiting to {limit} examples")
        ds = ds.select(range(limit))

    data_dir = Path(data_dir)
    data_dir.mkdir(exist_ok=True, parents=True)

    def process(example):
        outfile_path = str(data_dir / f"{example['ytid']}.wav")
        status = True
        if not os.path.exists(outfile_path):
            status = False
            status, log = download_clip(
                example['ytid'],
                outfile_path,
                example['start_s'],
                example['end_s'],
            )

        example['audio'] = outfile_path
        example['download_status'] = status
        return example

    return ds.map(
        process,
        num_proc=num_proc,
        writer_batch_size=writer_batch_size,
        keep_in_memory=False
    ).cast_column('audio', Audio(sampling_rate=sampling_rate))

# %% [markdown]
# ## Load the Dataset
#
# Here we are limiting to the first 32 examples. Since Colab is constrained to 2 cores, downloading the whole dataset here would take hours.
#
# When running this on your own machine:
#   - you can set `limit=None` to download + process the full dataset. Feel free to do that here in Colab, it'll just take a long time.
#   - you should increase the `num_proc`, which will speed things up substantially
#   - If you run out of memory, try reducing the `writer_batch_size`, as by default, it will keep 1000 examples in memory *per worker*.

# %%
ds = main('./music_data', num_proc=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ds = main('./music_data', num_proc=2)
#
# Cell In[5], line 57, in main(data_dir, sampling_rate, limit, num_proc, writer_batch_size)
#      40 def main(
#      41     data_dir: str,
#      42     sampling_rate: int = 44100,
#    (...)
#      45     writer_batch_size: int = 1000,
#      46 ):
#      47     """
#      48     Download the clips within the MusicCaps dataset from YouTube.
#      49     Args:
#    (...)
#      54         writer_batch_size: Batch size for writing the dataset. This is per process.
#      55     """
# ---> 57     ds = load_dataset('google/MusicCaps', split='train')
#      58     if limit is not None:
#      59         print(f"Limiting to {limit} examples")
#
# File ~/miniforge3/envs/deep/lib/python3.9/site-packages/datasets/load.py:2592, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2587 verification_mode = VerificationMode(
#    2588     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2589 )
#    2591 # Create a dataset builder
# -> 2592 builder_instance = load_dataset_builder(
#    2593     path=path,
#    2594     name=name,
#    2595     data_dir=data_dir,
#    2596     data_files=data_files,
#    2597     cache_dir=cache_dir,
#    2598     features=features,
#    2599     download_config=download_config,
#    2600     download_mode=download_mode,
#    2601     revision=revision,
#    2602     token=token,
#    2603     storage_options=storage_options,
#    2604     trust_remote_code=trust_remote_code,
#    2605     _require_default_config_name=name is None,
#    2606     **config_kwargs,
#    2607 )
#    2609 # Return iterable dataset in case of streaming
#    2610 if streaming:
#
# File ~/miniforge3/envs/deep/lib/python3.9/site-packages/datasets/load.py:2264, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    2262     download_config = download_config.copy() if download_config else DownloadConfig()
#    2263     download_config.storage_options.update(storage_options)
# -> 2264 dataset_module = dataset_module_factory(
#    2265     path,
#    2266     revision=revision,
#    2267     download_config=download_config,
#    2268     download_mode=download_mode,
#    2269     data_dir=data_dir,
#    2270     data_files=data_files,
#    2271     cache_dir=cache_dir,
#    2272     trust_remote_code=trust_remote_code,
#    2273     _require_default_config_name=_require_default_config_name,
#    2274     _require_custom_configs=bool(config_kwargs),
#    2275 )
#    2276 # Get dataset builder class from the processing script
#    2277 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/miniforge3/envs/deep/lib/python3.9/site-packages/datasets/load.py:1915, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1910             if isinstance(e1, FileNotFoundError):
#    1911                 raise FileNotFoundError(
#    1912                     f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory. "
#    1913                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1914                 ) from None
# -> 1915             raise e1 from None
#    1916 else:
#    1917     raise FileNotFoundError(
#    1918         f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory."
#    1919     )
#
# File ~/miniforge3/envs/deep/lib/python3.9/site-packages/datasets/load.py:1860, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1847     download_config = download_config.copy() if download_config else DownloadConfig()
#    1848     download_config.storage_options.update(storage_options)
#    1849 dataset_module = dataset_module_factory(
#    1850     path,
#    1851     revision=revision,
#    1852     download_config=download_config,
#    1853     download_mode=download_mode,
#    1854     data_dir=data_dir,
#    1855     data_files=data_files,
#    1856     cache_dir=cache_dir,
#    1857     trust_remote_code=trust_remote_code,
#    1858     _require_default_config_name=_require_default_config_name,
#    1859     _require_custom_configs=bool(config_kwargs),
# -> 1860 )
#    1861 # Get dataset builder class from the processing script
#    1862 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/miniforge3/envs/deep/lib/python3.9/site-packages/datasets/load.py:1833, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1740 def load_dataset_builder(
#    1741     path: str,
#    1742     name: Optional[str] = None,
#    (...)
#    1754     **config_kwargs,
#    1755 ) -> DatasetBuilder:
#    1756     """Load a dataset builder which can be used to:
#    1757
#    1758     - Inspect general information that is required to build a dataset (cache directory, config, dataset info, features, data files, etc.)
#    1759     - Download and prepare the dataset as Arrow files in the cache
#    1760     - Get a streaming dataset without downloading or caching anything
#    1761
#    1762     You can find the list of datasets on the [Hub](https://huggingface.co/datasets) or with [`huggingface_hub.list_datasets`].
#    1763
#    1764     A dataset is a directory that contains some data files in generic formats (JSON, CSV, Parquet, etc.) and possibly
#    1765     in a generic structure (Webdataset, ImageFolder, AudioFolder, VideoFolder, etc.)
#    1766
#    1767     Args:
#    1768
#    1769         path (`str`):
#    1770             Path or name of the dataset.
#    1771
#    1772             - if `path` is a dataset repository on the HF hub (list all available datasets with [`huggingface_hub.list_datasets`])
#    1773               -> load the dataset builder from supported files in the repository (csv, json, parquet, etc.)
#    1774               e.g. `'username/dataset_name'`, a dataset repository on the HF hub containing the data files.
#    1775
#    1776             - if `path` is a local directory
#    1777               -> load the dataset builder from supported files in the directory (csv, json, parquet, etc.)
#    1778               e.g. `'./path/to/directory/with/my/csv/data'`.
#    1779
#    1780             - if `path` is the name of a dataset builder and `data_files` or `data_dir` is specified
#    1781               (available builders are "json", "csv", "parquet", "arrow", "text", "xml", "webdataset", "imagefolder", "audiofolder", "videofolder")
#    1782               -> load the dataset builder from the files in `data_files` or `data_dir`
#    1783               e.g. `'parquet'`.
#    1784
#    1785             It can also point to a local dataset script but this is not recommended.
#    1786         name (`str`, *optional*):
#    1787             Defining the name of the dataset configuration.
#    1788         data_dir (`str`, *optional*):
#    1789             Defining the `data_dir` of the dataset configuration. If specified for the generic builders (csv, text etc.) or the Hub datasets and `data_files` is `None`,
#    1790             the behavior is equal to passing `os.path.join(data_dir, **)` as `data_files` to reference all the files in a directory.
#    1791         data_files (`str` or `Sequence` or `Mapping`, *optional*):
#    1792             Path(s) to source data file(s).
#    1793         cache_dir (`str`, *optional*):
#    1794             Directory to read/write data. Defaults to `"~/.cache/huggingface/datasets"`.
#    1795         features ([`Features`], *optional*):
#    1796             Set the features type to use for this dataset.
#    1797         download_config ([`DownloadConfig`], *optional*):
#    1798             Specific download configuration parameters.
#    1799         download_mode ([`DownloadMode`] or `str`, defaults to `REUSE_DATASET_IF_EXISTS`):
#    1800             Download/generate mode.
#    1801         revision ([`Version`] or `str`, *optional*):
#    1802             Version of the dataset script to load.
#    1803             As datasets have their own git repository on the Datasets Hub, the default version "main" corresponds to their "main" branch.
#    1804             You can specify a different version than the default "main" by using a commit SHA or a git tag of the dataset repository.
#    1805         token (`str` or `bool`, *optional*):
#    1806             Optional string or boolean to use as Bearer token for remote files on the Datasets Hub.
#    1807             If `True`, or not specified, will get token from `"~/.huggingface"`.
#    1808         storage_options (`dict`, *optional*, defaults to `None`):
#    1809             **Experimental**. Key/value pairs to be passed on to the dataset file-system backend, if any.
#    1810
#    1811             <Added version="2.11.0"/>
#    1812         trust_remote_code (`bool`, defaults to `False`):
#    1813             Whether or not to allow for datasets defined on the Hub using a dataset script. This option
#    1814             should only be set to `True` for repositories you trust and in which you have read the code, as it will
#    1815             execute code present on the Hub on your local machine.
#    1816
#    1817             <Added version="2.16.0"/>
#    1818
#    1819             <Changed version="2.20.0">
#    1820
#    1821             `trust_remote_code` defaults to `False` if not specified.
#    1822
#    1823             </Changed>
#    1824
#    1825         **config_kwargs (additional keyword arguments):
#    1826             Keyword arguments to be passed to the [`BuilderConfig`]
#    1827             and used in the [`DatasetBuilder`].
#    1828
#    1829     Returns:
#    1830         [`DatasetBuilder`]
#    1831
#    1832     Example:
# -> 1833
#    1834     ```py
#    1835     >>> from datasets import load_dataset_builder
#    1836     >>> ds_builder = load_dataset_builder('cornell-movie-review-data/rotten_tomatoes')
#    1837     >>> ds_builder.info.features
#    1838     {'label': ClassLabel(names=['neg', 'pos'], id=None),
#    1839      'text': Value(dtype='string', id=None)}
#    1840     ```
#    1841     """
#    1842     download_mode = DownloadMode(download_mode or DownloadMode.REUSE_DATASET_IF_EXISTS)
#    1843     if token is not None:
#
# File ~/miniforge3/envs/deep/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/miniforge3/envs/deep/lib/python3.9/site-packages/huggingface_hub/hf_api.py:2366, in HfApi.dataset_info(self, repo_id, revision, timeout, files_metadata, token)
#    2364 hf_raise_for_status(r)
#    2365 data = r.json()
# -> 2366 return DatasetInfo(**data)
#
# File ~/miniforge3/envs/deep/lib/python3.9/site-packages/huggingface_hub/hf_api.py:799, in DatasetInfo.__init__(self, **kwargs)
#     797 self.likes = kwargs.pop("likes")
#     798 self.paperswithcode_id = kwargs.pop("paperswithcode_id", None)
# --> 799 self.tags = kwargs.pop("tags")
#     800 card_data = kwargs.pop("cardData", None) or kwargs.pop("card_data", None)
#     801 self.card_data = (
#     802     DatasetCardData(**card_data, ignore_metadata_errors=True) if isinstance(card_data, dict) else card_data
#     803 )
#
# KeyError: 'tags'

# %% [markdown]
# Let's explore the samples using a quick Gradio Interface 🤗

# %%
import gradio as gr

def get_example(idx):
    ex = ds[idx]
    return ex['audio']['path'], ex['caption']

gr.Interface(
    get_example,
    inputs=gr.Slider(0, len(ds) - 1, value=0, step=1),
    outputs=['audio', 'textarea'],
    live=True
).launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://516473067ef97b640c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://516473067ef97b640c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
